# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
dd=pd.read_csv('/content/Real estate valuation data set.csv')
print(dd)
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
x=dd['X1 transaction date']
y=dd['Y house price of unit area']
from matplotlib import pyplot as pt 
pt.scatter(x,y)

# %%
x=dd['X2 house age']
y=dd['Y house price of unit area']
from matplotlib import pyplot as pt 
pt.scatter(x,y)

# %%
x=dd['X3 distance to the nearest MRT station']
y=dd['Y house price of unit area']
from matplotlib import pyplot as pt 
pt.scatter(x,y)

# %%
x=dd['X4 number of convenience stores']
y=dd['Y house price of unit area']
from matplotlib import pyplot as pt 
pt.scatter(x,y)

# %%
x=dd['X5 latitude']
y=dd['Y house price of unit area']
from matplotlib import pyplot as pt 
pt.scatter(x,y)

# %%
x=dd['X6 longitude']
y=dd['Y house price of unit area']
from matplotlib import pyplot as pt 
pt.scatter(x,y)
